# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from scipy.special import erf

# %%
x=np.linspace(-10,10,100)
y=np.linspace(-5,5,100)

# %%
xlow=-.0001
xhigh=.0001
z=erf(x-xlow) * erf(-x+xhigh)

# %%
plot(x,z);
plot(x,erf(x-xlow),label='low');
plot(x,erf(-x+xhigh),'r',label='high');
legend();

# %%
def timerf(x,xlow,xhigh):
    return 0.5*(erf(x-xlow)+erf(-(x-xhigh)))

# %%
xlow=-2.5
xhigh=2.5
plot(x,timerf(x,xlow,xhigh));
plot(x,erf(x-xlow),label='low');
plot(x,erf(-x+xhigh),'r',label='high');
legend();
